# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\glaks\Desktop\employee salary prediction\Salary_prediction\dataset.csv.csv")
data.head(10)
# Out:
#    Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing        Manager                 9
# 1            1   53  Female        Sales       Engineer                10
# 2            2   59  Female    Marketing        Analyst                 8
# 3            3   42  Female  Engineering        Manager                 1
# 4            4   44  Female        Sales       Engineer                10
# 5            5   47    Male        Sales  HR Specialist                10
# 6            6   58    Male    Marketing  HR Specialist                 5
# 7            7   57  Female        Sales        Analyst                 8
# 8            8   34  Female      Finance     Accountant                 6
# 9            9   57  Female    Marketing       Engineer                 7
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
# 5            0.889018                    237                      0   97212
# 6            0.688977                    155                      1   97865
# 7            0.981679                    171                      0   50113
# 8            0.010381                    177                      1   88747
# 9            0.466782                    170                      0   43283
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0
# 5          0
# 6          0
# 7          0
# 8          1
# 9          0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            1000 non-null   int64
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   object
#  3   Department             1000 non-null   object
#  4   Job_Title              1000 non-null   object
#  5   Years_at_Company       1000 non-null   int64
#  6   Satisfaction_Level     1000 non-null   float64
#  7   Average_Monthly_Hours  1000 non-null   int64
#  8   Promotion_Last_5Years  1000 non-null   int64
#  9   Salary                 1000 non-null   int64
#  10  Attrition              1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
data.isna()
# Out:
#      Employee_ID    Age  Gender  Department  Job_Title  Years_at_Company  \
# 0          False  False   False       False      False             False
# 1          False  False   False       False      False             False
# 2          False  False   False       False      False             False
# 3          False  False   False       False      False             False
# 4          False  False   False       False      False             False
# ..           ...    ...     ...         ...        ...               ...
# 995        False  False   False       False      False             False
# 996        False  False   False       False      False             False
# 997        False  False   False       False      False             False
# 998        False  False   False       False      False             False
# 999        False  False   False       False      False             False
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0                 False                  False                  False   False
# 1                 False                  False                  False   False
# 2                 False                  False                  False   False
# 3                 False                  False                  False   False
# 4                 False                  False                  False   False
# ..                  ...                    ...                    ...     ...
# 995               False                  False                  False   False
# 996               False                  False                  False   False
# 997               False                  False                  False   False
# 998               False                  False                  False   False
# 999               False                  False                  False   False
#
#      Attrition
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 995      False
# 996      False
# 997      False
# 998      False
# 999      False
#
# [1000 rows x 11 columns]

# %%
data.isna().sum()
# Out:
# Employee_ID              0
# Age                      0
# Gender                   0
# Department               0
# Job_Title                0
# Years_at_Company         0
# Satisfaction_Level       0
# Average_Monthly_Hours    0
# Promotion_Last_5Years    0
# Salary                   0
# Attrition                0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.head()
# Out:
#    Employee_ID  Age  Gender   Department Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing   Manager                 9
# 1            1   53  Female        Sales  Engineer                10
# 2            2   59  Female    Marketing   Analyst                 8
# 3            3   42  Female  Engineering   Manager                 1
# 4            4   44  Female        Sales  Engineer                10
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0

# %%
data.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Job_Title',
#        'Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours',
#        'Promotion_Last_5Years', 'Salary', 'Attrition'],
#       dtype='object')

# %%
data.drop(columns= "Employee_ID",inplace=True)

# %%
data.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\glaks\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\glaks\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\glaks\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\glaks\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\glaks\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\glaks\appdata\roaming\python\python313\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\glaks\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\glaks\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\glaks\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\glaks\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\glaks\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt

# %%
data["Gender"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Gender Count of Employees")
plt.show()

# %%
data.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
data.groupby("Job_Title")["Salary"].mean().sort_values(ascending=False).plot(kind="line")
plt.title("Average Salary by Job Title")
plt.xlabel("Job Title")
plt.ylabel("Average Salary")
plt.show()

# %%
data.groupby(["Department","Promotion_Last_5Years"])["Salary"].mean().reset_index()
# Out:
#     Department  Promotion_Last_5Years        Salary
# 0  Engineering                      0  65541.063636
# 1  Engineering                      1  62424.127660
# 2      Finance                      0  63390.145299
# 3      Finance                      1  62041.269663
# 4           HR                      0  63012.556701
# 5           HR                      1  65882.861702
# 6    Marketing                      0  65251.597826
# 7    Marketing                      1  66018.632653
# 8        Sales                      0  64295.846939
# 9        Sales                      1  67838.756757

# %%
data.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
data.describe()
# Out:
#                Age  Years_at_Company  Satisfaction_Level  \
# count  1000.000000       1000.000000         1000.000000
# mean     42.205000          5.605000            0.505995
# std      10.016452          2.822223            0.289797
# min      25.000000          1.000000            0.001376
# 25%      33.000000          3.000000            0.258866
# 50%      43.000000          6.000000            0.505675
# 75%      51.000000          8.000000            0.761135
# max      59.000000         10.000000            0.999979
#
#        Average_Monthly_Hours  Promotion_Last_5Years        Salary    Attrition
# count            1000.000000            1000.000000   1000.000000  1000.000000
# mean              199.493000               0.486000  64624.980000     0.495000
# std                29.631908               0.500054  20262.984333     0.500225
# min               150.000000               0.000000  30099.000000     0.000000
# 25%               173.000000               0.000000  47613.500000     0.000000
# 50%               201.000000               0.000000  64525.000000     0.000000
# 75%               225.000000               1.000000  81921.000000     1.000000
# max               249.000000               1.000000  99991.000000     1.000000

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Department', 'Job_Title', 'Years_at_Company',
#        'Satisfaction_Level', 'Average_Monthly_Hours', 'Promotion_Last_5Years',
#        'Salary', 'Attrition'],
#       dtype='object')

# %%
data.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
X = data[["Years_at_Company","Satisfaction_Level","Average_Monthly_Hours"]]
y = data["Salary"]

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\glaks\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\glaks\appdata\roaming\python\python313\site-packages (from scikit-learn) (2.3.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\glaks\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\glaks\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\glaks\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X
# Out:
#      Years_at_Company  Satisfaction_Level  Average_Monthly_Hours
# 0                   9            0.586251                    151
# 1                  10            0.261161                    221
# 2                   8            0.304382                    184
# 3                   1            0.480779                    242
# 4                  10            0.636244                    229
# ..                ...                 ...                    ...
# 995                 3            0.377435                    239
# 996                 1            0.431152                    154
# 997                 3            0.647102                    206
# 998                 2            0.304813                    241
# 999                 1            0.940510                    159
#
# [1000 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.48409146,  1.3048254 ,  0.67184905],
#        [ 0.13009405,  0.21654281, -0.96555915],
#        [ 0.83808887,  0.50379569, -1.30668586],
#        ...,
#        [-0.22390336, -1.70052584,  1.42232781],
#        [-1.639893  ,  0.40668085,  0.56951104],
#        [-1.639893  ,  1.03314709,  0.67184905]], shape=(800, 3))

# %%
import joblib
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
X_test = scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[ 0.18024252,  0.63006263,  0.6092096 ],
#        [-0.17667336, -1.47404927, -0.1703708 ],
#        [-0.8905051 , -0.49569868,  0.38183199],
#        [-1.24742098, -0.26158022,  0.0245243 ],
#        [ 0.89407426, -1.54436405, -0.26781835],
#        [ 0.89407426,  0.71062503,  0.31686695],
#        [-1.24742098,  0.91867111, -0.94995121],
#        [-0.8905051 ,  0.45318747,  0.18693688],
#        [ 1.25099014,  1.38361271, -0.72257359],
#        [ 0.89407426,  1.04802716, -1.27477637],
#        [ 1.25099014,  0.14907488,  1.25885994],
#        [-0.8905051 ,  1.59672152,  1.48623756],
#        [-1.60433685,  0.86145081, -0.26781835],
#        [-1.60433685,  1.5406366 ,  1.35630749],
#        [-0.17667336,  1.48254757, -0.23533583],
#        [-0.17667336,  1.25783374, -1.04739876],
#        [ 1.25099014,  1.02857254, -1.43718896],
#        [ 1.25099014, -1.44089825,  0.44679702],
#        [ 0.18024252,  1.28910438, -1.56711903],
#        [ 1.60790601,  1.00642383,  1.12892987],
#        [ 0.53715839, -0.34065343,  1.19389491],
#        [-0.17667336,  1.01846608,  0.34934947],
#        [ 1.25099014,  1.38719463,  0.90155226],
#        [-1.24742098, -1.45964974, -1.43718896],
#        [ 0.18024252, -1.10384067, -0.1703708 ],
#        [ 0.53715839,  1.59449104,  0.38183199],
#        [-1.60433685,  0.71787998,  0.99899981],
#        [ 1.25099014,  0.13360568, -0.59264352],
#        [-1.60433685,  0.27624934,  0.86906974],
#        [ 0.53715839,  0.31068352, -0.39774842],
#        [-0.8905051 , -0.14581123, -1.43718896],
#        [-0.17667336, -1.2375309 ,  0.90155226],
#        [ 0.53715839, -1.49269961,  1.45375504],
#        [ 1.60790601, -1.17647789,  0.6092096 ],
#        [ 0.53715839, -0.5063113 ,  0.57672709],
#        [-1.24742098, -0.47974236,  0.18693688],
#        [ 1.25099014, -0.76997743, -1.50215399],
#        [-0.17667336,  0.28893058, -0.3652659 ],
#        [ 0.89407426,  1.56423749, -0.78753862],
#        [ 0.53715839, -0.05632528,  1.25885994],
#        [-1.24742098, -0.56742493, -1.43718896],
#        [-0.53358923, -0.72526567,  0.93403477],
#        [-0.17667336, -1.32000333, -1.46967147],
#        [-0.8905051 ,  0.59632317,  0.77162219],
#        [ 1.60790601, -1.27049813, -0.1703708 ],
#        [ 0.53715839, -0.19729869, -0.98243372],
#        [-0.8905051 ,  1.47758967, -0.1703708 ],
#        [ 0.89407426,  1.00960551,  0.86906974],
#        [-0.17667336, -0.36262986,  1.48623756],
#        [ 1.60790601,  1.3258714 ,  1.19389491],
#        [-1.24742098, -0.59770089, -0.39774842],
#        [-0.8905051 , -0.4966735 ,  0.12197185],
#        [-1.60433685,  1.68478741,  1.09644736],
#        [ 0.53715839, -0.88891611,  0.96651729],
#        [ 0.89407426, -1.75438235, -0.98243372],
#        [-1.24742098, -1.78617252,  1.32382497],
#        [ 0.89407426, -0.01367696, -1.50215399],
#        [-0.17667336,  1.72615161, -1.33974141],
#        [-1.60433685, -0.36584109,  0.51176205],
#        [ 0.89407426,  1.55518465, -1.63208406],
#        [ 0.53715839, -0.22614412, -1.01491624],
#        [-0.53358923, -1.07994782,  0.05700682],
#        [-0.53358923,  1.6163226 ,  0.38183199],
#        [ 0.18024252,  0.2620767 ,  0.90155226],
#        [-0.53358923,  0.82194487,  0.12197185],
#        [ 1.60790601,  0.96479324,  1.16141239],
#        [-0.17667336, -0.57303531, -0.72257359],
#        [-0.17667336, -1.21186843,  0.90155226],
#        [ 0.18024252, -1.70569881,  1.55120259],
#        [-0.53358923, -0.11272658, -1.04739876],
#        [ 1.25099014,  0.59944354, -1.14484631],
#        [ 0.53715839, -0.84257472,  1.32382497],
#        [-0.53358923,  0.44757885, -0.33278339],
#        [-0.8905051 , -0.58366117,  1.38879001],
#        [ 1.60790601, -0.22270064, -1.46967147],
#        [-0.8905051 ,  1.30315571,  1.45375504],
#        [-1.60433685, -1.03618174, -0.65760855],
#        [ 1.60790601, -1.61951239,  1.12892987],
#        [ 1.25099014, -0.61313547, -0.23533583],
#        [ 0.89407426, -0.93910685,  0.64169212],
#        [ 1.25099014,  0.30862078, -1.56711903],
#        [-1.60433685,  1.14736333,  1.58368511],
#        [-1.24742098, -0.78158738,  1.32382497],
#        [ 0.53715839, -1.26579461,  0.47927954],
#        [-1.24742098,  0.06858999,  0.90155226],
#        [ 0.53715839, -1.34540508,  1.06396484],
#        [ 0.53715839, -1.33602622, -1.53463651],
#        [-0.17667336,  1.15758951, -0.49519597],
#        [-0.17667336,  0.64424775,  1.38879001],
#        [ 1.25099014,  1.59237204,  1.55120259],
#        [-0.17667336, -0.68854309, -1.53463651],
#        [-0.8905051 ,  0.98078559, -1.37222392],
#        [ 1.60790601,  1.13124054, -1.14484631],
#        [-0.17667336,  1.06297707,  0.0245243 ],
#        [-0.53358923,  0.55264582, -0.88498617],
#        [ 0.89407426, -0.41093448, -0.39774842],
#        [ 1.25099014,  1.18890329,  0.05700682],
#        [-1.60433685, -1.42662441, -0.91746869],
#        [ 0.53715839,  0.41414863, -1.07988127],
#        [-0.53358923,  0.80225933, -1.40470644],
#        [ 0.53715839, -1.32656245,  0.57672709],
#        [ 0.89407426,  0.38937137,  0.6092096 ],
#        [ 1.25099014, -1.1537882 ,  0.44679702],
#        [-0.8905051 , -1.03359049,  1.22637742],
#        [ 0.53715839, -0.6057062 , -0.39774842],
#        [-1.60433685, -0.80280281,  0.08948933],
#        [ 0.89407426,  0.52752144, -0.78753862],
#        [-0.17667336, -0.03929034, -0.88498617],
#        [-1.60433685, -1.15684105, -0.98243372],
#        [ 1.25099014,  1.08487714,  1.35630749],
#        [-0.8905051 ,  0.02112579, -0.00795822],
#        [ 0.89407426, -1.34256508,  0.57672709],
#        [ 0.89407426, -0.25068138,  0.67417464],
#        [-1.60433685, -1.29283295, -0.59264352],
#        [ 0.18024252,  1.28338307, -0.59264352],
#        [ 1.60790601,  0.40102924,  0.05700682],
#        [-0.17667336,  1.26504377,  0.05700682],
#        [ 0.53715839,  0.34008954,  0.2194194 ],
#        [ 0.18024252,  0.80768501, -1.59960154],
#        [ 0.18024252, -1.23630577,  0.34934947],
#        [-0.8905051 , -0.22860029, -0.33278339],
#        [ 1.25099014,  0.3595039 ,  0.73913967],
#        [ 0.18024252,  0.08471246,  1.38879001],
#        [-0.8905051 , -0.80555606, -1.33974141],
#        [-0.8905051 , -0.5196105 ,  1.25885994],
#        [-1.60433685,  1.42769315,  1.32382497],
#        [ 0.89407426, -0.61386766, -1.56711903],
#        [ 0.89407426,  0.82653517,  1.06396484],
#        [ 1.25099014, -0.74867084,  1.25885994],
#        [-0.8905051 ,  0.38918301,  0.64169212],
#        [ 1.25099014,  0.14975825, -1.01491624],
#        [-0.8905051 ,  1.33828766,  0.54424457],
#        [-1.24742098,  1.32804697,  1.38879001],
#        [ 0.18024252,  1.27460411, -1.27477637],
#        [-1.60433685, -0.71980652, -0.52767849],
#        [ 0.18024252,  0.50927863, -1.59960154],
#        [-1.24742098,  0.8027292 ,  1.48623756],
#        [ 0.89407426,  0.48422915, -1.30725889],
#        [-0.17667336,  0.54207929,  1.45375504],
#        [ 0.89407426,  0.82366284, -1.14484631],
#        [ 0.18024252,  0.34131556, -1.33974141],
#        [-0.8905051 , -1.51495087, -0.13788828],
#        [ 0.53715839,  0.33619268,  0.73913967],
#        [-1.60433685, -0.32583104, -1.50215399],
#        [-0.8905051 ,  0.258402  , -1.50215399],
#        [-0.53358923,  1.54052587, -0.04044073],
#        [-0.53358923, -0.3035561 ,  0.64169212],
#        [ 0.53715839,  0.88965358,  1.48623756],
#        [-1.60433685, -1.4151585 , -0.00795822],
#        [ 1.25099014,  1.59604168,  0.31686695],
#        [ 0.53715839, -0.22921103,  0.2194194 ],
#        [ 0.18024252,  0.27042148, -0.52767849],
#        [ 0.89407426, -1.39307488,  1.12892987],
#        [-1.60433685, -0.78069934,  0.34934947],
#        [-1.60433685, -1.12437934,  1.55120259],
#        [-0.53358923, -1.85745383, -1.63208406],
#        [-1.60433685,  1.60889027,  0.15445437],
#        [-1.24742098,  0.62980696, -1.17732882],
#        [-0.17667336, -0.09021101, -0.33278339],
#        [-1.24742098, -1.10850197,  0.4143145 ],
#        [-0.53358923,  0.56339853,  0.28438444],
#        [ 0.89407426,  0.83640092,  0.44679702],
#        [-0.53358923, -0.19446376, -0.82002114],
#        [-0.17667336, -0.8808913 , -1.14484631],
#        [ 1.60790601, -0.60822472,  0.2194194 ],
#        [ 0.53715839,  1.69022573, -1.24229386],
#        [-1.60433685,  1.42487132,  1.58368511],
#        [-1.24742098, -1.58470268, -0.33278339],
#        [-1.24742098, -1.20831913,  0.96651729],
#        [ 1.60790601, -0.6005782 ,  0.08948933],
#        [-0.17667336, -0.85313025,  1.06396484],
#        [ 0.53715839, -1.02366292, -1.27477637],
#        [ 0.89407426, -0.69041238, -1.24229386],
#        [-1.24742098, -0.88723692,  1.38879001],
#        [-1.24742098, -1.12620401, -0.20285332],
#        [-1.24742098,  0.80204878, -1.63208406],
#        [ 1.60790601,  0.0230333 , -0.72257359],
#        [-1.24742098,  1.24091942,  0.57672709],
#        [-1.60433685,  1.60104079,  0.90155226],
#        [-0.17667336, -1.40428975,  0.96651729],
#        [ 1.25099014, -0.96823323,  1.38879001],
#        [ 0.18024252, -1.63437905, -1.43718896],
#        [-0.17667336,  0.60424391, -1.46967147],
#        [ 1.25099014, -1.79476646, -0.49519597],
#        [-0.17667336,  0.3447861 ,  0.15445437],
#        [-0.17667336, -0.83495335, -0.59264352],
#        [-0.17667336, -0.61514727,  0.70665715],
#        [ 0.18024252,  1.65003283,  0.64169212],
#        [-0.53358923,  1.21050328, -0.13788828],
#        [ 1.60790601, -0.19414537, -0.3652659 ],
#        [ 0.53715839, -0.20229689,  1.29134246],
#        [ 0.53715839,  0.14870889, -0.91746869],
#        [ 1.25099014,  0.83042494, -1.40470644],
#        [ 0.89407426, -0.35000055,  1.03148232],
#        [ 1.25099014, -0.00995535, -1.01491624],
#        [ 0.89407426,  0.60246691, -1.30725889],
#        [ 0.18024252, -1.42775754, -0.560161  ],
#        [-0.17667336,  0.24320511,  1.16141239],
#        [ 0.18024252, -1.19188198,  1.16141239],
#        [ 1.60790601, -0.17981071, -1.20981134]])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

def results(predictions):
  print("Mean absolute error on model is {}",format(mean_absolute_error(y_test,predictions)))
  print("Root maen squared error on model is {}",format(np.sqrt(mean_squared_error(y_test,predictions))))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictionlr = lr.predict(X_test)

# %%
results(predictionlr)
# Out:
# Mean absolute error on model is {} 16937.191614215193
# Root maen squared error on model is {} 20003.033913810832

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# %%
svrmodel = SVR()

# %%
param_gridsvr = {
    'C': [0.1, 1, 10],
    'epsilon': [0.1, 0.2, 0.5],
    'kernel': ['linear', 'poly', 'rbf'],  # Ensure valid kernel types
    'degree': [2, 3, 4],  # Only applicable if 'poly' kernel is used
}

# %%
gridsvr = GridSearchCV(svrmodel, param_gridsvr)

# %%
gridsvr.fit(X_train, y_train.values.ravel())
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 4],
#                          'epsilon': [0.1, 0.2, 0.5],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
gridsvr.best_params_
# Out:
# {'C': 0.1, 'degree': 2, 'epsilon': 0.1, 'kernel': 'rbf'}

# %%
predictionssvr = gridsvr.predict(X_test)

# %%
results(predictionssvr)
# Out:
# Mean absolute error on model is {} 17082.903401312906
# Root maen squared error on model is {} 20133.747818034914

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rfmodel = RandomForestRegressor()

# %%
param_gridrfr = {
    "n_estimators": [2, 3, 4, 5, 6],  # Use a list instead of a set
    "max_depth": [5, 10, 15]
}

# %%
gridrfr = GridSearchCV(estimator=rfmodel, param_grid=param_gridrfr, cv=5)

# %%
gridrfr.fit(X_train, y_train.values.ravel())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 5, 6]})

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 5}

# %%
predictionofrfr = gridrfr.predict(X_test)

# %%
results(predictionofrfr)
# Out:
# Mean absolute error on model is {} 17546.567638807217
# Root maen squared error on model is {} 20833.741917865867

# %%
lr
# Out:
# LinearRegression()

# %%
joblib.dump(lr, "model.pkl")
# Out:
# ['model.pkl']

# %%
X.columns
# Out:
# Index(['Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours'], dtype='object')
